# %%
# %pip install lxml
import xml.etree.ElementTree as ET

try:
    from lxml import etree
    print('lxml running')
except:
    print ('no lxml')
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 4.0/4.0 MB 21.8 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# lxml running
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# need to add lxml? what
#
# had to use pip install, in jupyter notebook need to use '%'

# %%
from pathlib import Path
import re

MODS_collection_5 = Path('/','OneDrive', 'Desktop','2018_lcwa_MODS_5.xml')
print(MODS_collection_5)

mods = etree.parse(MODS_collection_5)
metadata = mods.getroot()

for item in metadata:
    print(item.tag)
# Out:
# \OneDrive\Desktop\2018_lcwa_MODS_5.xml
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 7
#       4 MODS_collection_5 = Path('/','OneDrive', 'Desktop','2018_lcwa_MODS_5.xml')
#       5 print(MODS_collection_5)
# ----> 7 mods = etree.parse(MODS_collection_5)
#       8 metadata = mods.getroot()
#      10 for item in metadata:
#
# File src/lxml/etree.pyx:3711, in lxml.etree.parse()
#
# File src/lxml/parser.pxi:2031, in lxml.etree._parseDocument()
#
# File src/lxml/parser.pxi:2057, in lxml.etree._parseDocumentFromURL()
#
# File src/lxml/parser.pxi:1958, in lxml.etree._parseDocFromFile()
#
# File src/lxml/parser.pxi:1230, in lxml.etree._BaseParser._parseDocFromFile()
#
# File src/lxml/parser.pxi:647, in lxml.etree._ParserContext._handleParseResultDoc()
#
# File src/lxml/parser.pxi:765, in lxml.etree._handleParseResult()
#
# ...

# %%
el_count = 0

for element in metadata.iter():
    el_count += 1
    print(element.tag)

print(el_count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 el_count = 0
# ----> 3 for element in metadata.iter():
#       4     el_count += 1
#       5     print(element.tag)
#
# NameError: name 'metadata' is not defined

# %% [markdown]
# for wanting to find elements?? idk i need to rewatch the lecture!

# %%
for identifier in metadata.findall('.//modds:identifier', namespaces=ns):
    element = identifier
    print(element.tag, element.attrib, element.text)

# %% [markdown]
# for wanting to find uris and things

# %%
for identifier in metadata.findall('.//mods:identifier[@type="uri"]', namespaces=ns):
    print(identifier.tag, identifier.attrib, identifier.text)
