# %% [markdown]
# goal is to get an inventory and then transform that into a csv file to facilitate upload

# %%
import json
import Path

collection_json([attribute], [attribute2], [attribute3])

collection_setlist = Path('collection_set_list.csv')
with open(collection_set_list, 'w', encoding='utf-8', newline=' ') as f:
    writer = csv.DictWriter(f, fieldnames=['image', 'link', 'title'])
    writer.writeheader()

    for item in collection_json['content']['set']['items']:
        item['tite'] = item['title'].rstrip()
        writer.writerow(item)

# %% [markdown]
# check the files xpath-mods-apis.ipynb

# %% [markdown]
# getting the stuff steps:
#
# get the metadata(:
# using the link fields to look for the items
# loc.gov-----/?fo=json

# %%
if '?' in item['link']:
    resource_ID = item['link']
    short_ID - item['link'].split(/)

# %% [markdown]
# check the examples and modify the path
